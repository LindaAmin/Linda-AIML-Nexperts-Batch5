# %% [markdown]
# ## Streamlit
# -
# - Streamlit is aphython tool to help turn python scripts into webpages (Dashboards)
# -
# - instead of learning about Front end development entirely new subject
# - use this library to build front ends

# %% [markdown]
# ```
# st.title()
# st.write()
# st.slider()
# st.line_chart()

# %% [markdown]
# - can build data dashboards
# - demo applications
# - simple forms
# - portfolio projects
# - prototyping

# %%
# pip install streamlit

# %% [markdown]
# - You can only run the streamlit using a script
# - create a script with the streamlit code
# - go to terminal
# - type:
#     `streamlit run <filename.py>`

# %%
import streamlit as st

# to write something
st.title("First Streamlit App")

# create a slider and store number in a variable
age = st.slider("How old are you?", 1, 100, 25)

# %% [markdown]
# We can show data tables in streamlit as well

# %%
import pandas as pd
data = {
    "Days": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"],
    "Cups of Coffee": [1, 2, 4, 3, 5]
}
coffee_table = pd.DataFrame(data)
st.write("Here is the data:")
st.dataframe(coffee_table)

# %% [markdown]
# #### Displaying a chart

# %%
st.write("Here is the visual chart:")
st.bar_chart(coffee_table, x="Days", y="Cups of Coffee")

# %% [markdown]
# ## Inputs in Streamlit

# %%
# use text_input() for shorter answers - name, password, search queries etc
name = st.text_input("What is your name?")


# longer text - paragraphs
feedback = st.text_area("Leave your comments here:")

# %%
# choice inputs

size = st.radio("Pick a size:", ["Small", "Medium", "Large"])

country = st.selectbox("Where are you from?", ["India", "Malaysia", "USA", "UK"])

skills = st.multiselect("Select your skills:", ["Python", "SQL", "Power BI", "AI"])

# %%
# boolean Inputs

agree = st.checkbox("I agree to the terms")

# %%
# toogle Switch for choices

dark_mode = st.toggle("Enable Dark Mode")
