# %% [markdown]
# ### Step 1: Get Your Access Token
# Before you touch the terminal, you need your secret password (API Key/Token).
#
# Log in to your account on the Hugging Face website.
#
# Click your profile picture in the top right corner and select Settings.
#
# On the left sidebar, click Access Tokens.
#
# Click the New token button.
#
# Tip: If you only want to download private models, a "Read" token is fine. If you want to upload your own models or datasets, create a "Write" token.
#
# Copy the generated token to your clipboard.

# %% [markdown]
# pip install -U huggingface_hub
#
# You need the official Hugging Face Python library installed to use their command-line tool.

# %% [markdown]
# then:
#
# hf auth login
#
# User is already logged in. Use `hf auth login --force` to force re-login.

# %% [markdown]
# `hf auth whoami`
#
# This will print out the username associated with the currently saved token.

# %% [markdown]
# Error: Invalid user token. The token stored is invalid. Please run `hf auth login --force` to set a new token.
# Set HF_DEBUG=1 as environment variable for full traceback.
#
#
#
# The token was accidentally deleted or revoked on the Hugging Face website.
#
# The token expired (if you set an expiration date when you created it).

# %% [markdown]
# Generate a Brand New Token
# Since the current token is broken, you need a fresh one.
#
# Go back to your Hugging Face Access Tokens page.
#
# I highly recommend clicking the Delete button next to your old token so you don't confuse them later.
#
# Click New token, give it a name, and copy the new string to your clipboard.

# %% [markdown]
# Create

# %% [markdown]
# `hf auth login --force`
#
# enter new token
#
# `hf auth whoami`

# %% [markdown]
# gradio deploy
#
# enter app name
