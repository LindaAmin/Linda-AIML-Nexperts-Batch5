# %%
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# Samples data
data = np.array([[1, 2], [2, 3], [5, 8], [8, 8], [1, 0], [0, 1]])

# Applies agglomerative clustering using Ward's method
Z = linkage(data, method='ward')

# Plots dendrogram
plt.figure(figsize=(8, 4))
dendrogram(Z)
plt.title('Agglomerative Clustering Dendrogram')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# Extracts clusters (e.g., form 2 clusters)
clusters = fcluster(Z, t=2, criterion='maxclust')
print("Cluster assignments:", clusters)
# Out:
# Cluster assignments: [2 2 1 1 2 2]

# %% [markdown]
# Hierarchical clustering
# - is an unsupervised machine learning algorithm used to group similar data points into clusters
#
# - It builds a tree-like structure (dendrogram) that represents the nested grouping of data points

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import AgglomerativeClustering

from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# Loads the dataset

data = {
    'CustomerID': [1, 2, 3, 4, 5, 6],     
    'Age': [25, 26, 60, 62, 22, 65],     
    'SpendingScore': [80, 85, 15, 10, 88, 20] 
} 

df = pd.DataFrame(data) 
print("--- Original Data ---") 
print(df.head())
# Out:
# --- Original Data ---
#    CustomerID  Age  SpendingScore
# 0           1   25             80
# 1           2   26             85
# 2           3   60             15
# 3           4   62             10
# 4           5   22             88

# %%
# Feature selection - features that we want to cluster by
X = df[['Age', 'SpendingScore']]

# %%
# Create a Dendrogram to visualize the hierarchical clustering
# 1. Linkage matrix using Ward's method
Z = linkage(X, method='ward')

# 2. Plot the dendrogram
dendrogram(Z)

plt.axhline(y=20, color='r', linestyle='--')  # Example threshold for cutting the dendrogram

plt.show()

# %%
# Hierarchical model
# n_clusters is # of clusters we want to form. to cut the tree of the hierarchical clustering dendrogram at a certain level, we can specify the number of clusters we want to form. In this case, we want to form 2 clusters.
# metric = 'euclidean' is the distance metric used to compute the linkage
# linkage='ward is the linkage criterion used to minimize the variance of clusters being merged

hc_model = AgglomerativeClustering(n_clusters=2, metric = 'euclidean', linkage='ward')

# %%
# Trains the model and predicts the clusters for each data point in X
cluster = hc_model.fit_predict(X)

df['H Clusters'] = clusters

# %%
df
# Out:
#    CustomerID  Age  SpendingScore  H Clusters
# 0           1   25             80           2
# 1           2   26             85           2
# 2           3   60             15           1
# 3           4   62             10           1
# 4           5   22             88           2
# 5           6   65             20           2

# %% [markdown]
# - Divisive clusetering you won't really find in Sci-Kit Learn because it is computationally intensive
# - you have a large cluter of a big dataset, figuring out every possible way of splitting that data is tough for the computer
