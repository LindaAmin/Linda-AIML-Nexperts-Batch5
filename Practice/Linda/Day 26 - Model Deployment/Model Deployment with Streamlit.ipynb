# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

st.title("First Streamlit App")
# Out:
# 2026-07-05 15:03:16.909 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 15:03:17.588
# ...
#   command:
#
#     streamlit run C:\Users\User\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-05 15:03:17.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-05 15:03:17.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
#  Local URL: http://localhost:8501
#   Network URL: http://192.168.0.22:8501

# %%
#python -m pip install --upgrade streamlit

# python -m pip install --force-reinstall streamlit
# Out:
#   Cell In[8], line 3
#     python -m pip install --force-reinstall streamlit
#               ^
# SyntaxError: invalid syntax

# %%
#streamlit run app.py
# Out:
#   Cell In[11], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax

# %%
python -m streamlit run app.py
# Out:
#   Cell In[12], line 1
#     python -m streamlit run app.py
#               ^
# SyntaxError: invalid syntax

# %%
cd "Practice\Linda\Day 26 - Model Deployment"
# Out:
# [WinError 3] The system cannot find the path specified: 'Practice\\Linda\\Day 26 - Model Deployment'
# c:\Users\User\Desktop\AIML\Linda-AIML-Nexperts-Batch5\Practice\Linda\Day 26 - Model Deployment

# %% [markdown]
# python --version
#
# python -m streamlit --version
#
# cd "C:\Users\User\Desktop\AIML\Linda-AIML-Nexperts-Batch5\Practice\Linda\Day 26 - Model Deployment"
#
# dir
#
# after copy path - cd <copy path>
# python -m streamlit run app.py - **key word**
#
# python -m streamlit run app.py
#
# cd "C:\Users\User\Desktop\AIML\Linda-AIML-Nexperts-Batch5\Practice\Linda\Day 26 - Model Deployment"
#
# python -m streamlit run "Practice\Linda\Day 26 - Model Deployment\app.py"
