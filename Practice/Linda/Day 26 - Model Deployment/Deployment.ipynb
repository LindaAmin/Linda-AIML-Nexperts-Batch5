# %%
pip install gradio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\User\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import gradio as gr
import joblib

# %%
import pandas as pd

# %%
import warnings
warnings

# %%
input_cols = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean concavity', 'mean concave points', 'radius error', 'perimeter error', 'area error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst concave points']

model = joblib.load("breast_cancer_model.pk1")

model.predict([[0.1015, 0.03821, 677.9, 14.97, 12.47, 30.29, 0.3961, 81.09, 0.2378, 96.05, 0.2671, 24.64, 0.02701, 481.9, 0.09965]])

#def predict_cancer(input_cols):
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 input_cols = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean concavity', 'mean concave points', 'radius error', 'perimeter error', 'area error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst concave points']
#       2
# ----> 3 model = joblib.load("breast_cancer_model.pk1")
#       4
#       5 model.predict([[0.1015, 0.03821, 677.9, 14.97, 12.47, 30.29, 0.3961, 81.09, 0.2378, 96.05, 0.2671, 24.64, 0.02701, 481.9, 0.09965]])
#       6
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
# ...

# %%
app = gr.interface(
    fn - ,
    input = ,
    output = ,
    
)
